# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("USA_Housing.csv")

# %%
print(df)
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                             4.09     23086.800503  1.059034e+06
# 1                             3.09     40173.072174  1.505891e+06
# 2                             5.13     36882.159400  1.058988e+06
# 3                             3.26     34310.242831  1.260617e+06
# 4                             4.23     26354.109472  6.309435e+05
# ...                            ...              ...           ...
# 4995                          3.46     22837.361035  1.060194e+06
# 4996                          4.02     25616.115489  1.482618e+06
# 4997                          2.13     33266.145490  1.030730e+06
# 4998                          5.44     42625.620156  1.198657e+06
# 4999                          4.07     46501.283803  1.298950e+06
#
#                                                 Address
# 0     208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1     188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2     9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3                             USS Barnett\nFPO AP 44820
# 4                            USNS Raymond\nFPO AE 09386
# ...                                                 ...
# 4995                   USNS Williams\nFPO AP 30153-7653
# 4996              PSC 9258, Box 8489\nAPO AA 42991-3352
# 4997  4215 Tracy Garden Suite 076\nJoshualand, VA 01...
# 4998                          USS Wallace\nFPO AE 73316
# 4999  37778 George Ridges Apt. 509\nEast Holly, NV 2...
#
# [5000 rows x 7 columns]

# %%
x=df["Avg. Area House Age"]
y=df["Price"]
plt.plot(x,y)

# %%
a=df.iloc[:10,1]
b=df.iloc[:10,5]
plt.plot(a,b)

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 5000 artists>

# %%
plt.bar(a,b)
# Out:
# <BarContainer object of 10 artists>

# %%
plt.hist(a)
# Out:
# (array([1., 0., 2., 1., 1., 3., 0., 0., 0., 2.]),
#  array([4.42367179, 4.70012822, 4.97658465, 5.25304108, 5.52949751,
#         5.80595394, 6.08241037, 6.3588668 , 6.63532323, 6.91177966,
#         7.18823609]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(a,b)

# %%
# plt.pie(data,labels="")
#data=df["Area Population"]
#c=df["Address"]
#plt.pie(data,labels=c)

# %%
data=df.iloc[ :10,4]
c=df.iloc[ :10,6]
plt.pie(data,labels=c)
# Out:
# ([<matplotlib.patches.Wedge at 0x1f6474a7d90>,
#   <matplotlib.patches.Wedge at 0x1f647830590>,
#   <matplotlib.patches.Wedge at 0x1f647832010>,
#   <matplotlib.patches.Wedge at 0x1f647833790>,
#   <matplotlib.patches.Wedge at 0x1f6477ff710>,
#   <matplotlib.patches.Wedge at 0x1f6477fe250>,
#   <matplotlib.patches.Wedge at 0x1f6477fce50>,
#   <matplotlib.patches.Wedge at 0x1f6477fffd0>,
#   <matplotlib.patches.Wedge at 0x1f6477fe990>,
#   <matplotlib.patches.Wedge at 0x1f647718810>],
#  [Text(1.077049283712426, 0.22352816479036938, '208 Michael Ferry Apt. 674\nLaurabury, NE 37010-5101'),
#   Text(0.7932585507371924, 0.7620635614450604, '188 Johnson Views Suite 079\nLake Kathleen, CA 48958'),
#   Text(0.13437422490658868, 1.0917616808080204, '9127 Elizabeth Stravenue\nDanieltown, WI 06482-3489'),
#   Text(-0.5356100700401479, 0.9607923047524829, 'USS Barnett\nFPO AP 44820'),
#   Text(-0.9521138861839401, 0.5508894151603527, 'USNS Raymond\nFPO AE 09386'),
#   Text(-1.098405361571428, 0.059208628350442855, '06039 Jennifer Islands Apt. 443\nTracyport, KS 16077'),
#   Text(-0.8252473716397263, -0.7273010213121688, '4759 Daniel Shoals Suite 442\nNguyenburgh, CO 20247'),
#   Text(0.01586510076814492, -1.0998855843121216, '972 Joyce Viaduct\nLake William, TN 17778-6483'),
#   Text(0.6198069783741625, -0.9087570134852829, 'USS Gilbert\nFPO AA 20957'),
#   Text(1.0310763309607063, -0.38325135320388437, 'Unit 9446 Box 0958\nDPO AE 97025')])

# %%
sns.countplot(df["Avg. Area House Age"])
# Out:
# <Axes: ylabel='count'>

# %%
sns.histplot(df["Avg. Area House Age"])
# Out:
# <Axes: xlabel='Avg. Area House Age', ylabel='Count'>

# %%
sns.distplot(df["Avg. Area House Age"])
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_5520\1832924440.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Avg. Area House Age"])
# <Axes: xlabel='Avg. Area House Age', ylabel='Density'>

# %%
sns.lmplot(x="Avg. Area House Age", y="Price", data=df)

# %%
sns.heatmap(df.corr())
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_5520\58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >
